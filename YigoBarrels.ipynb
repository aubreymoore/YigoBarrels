# %%
# %load_ext sql
# %sql mysql+pymysql://trapper:tamuning@mysql.guaminsects.net/oryctes
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# u'Connected: trapper@oryctes'

# %%
# %sql SHOW TABLES
# Out:
# 39 rows affected.
# [('GMF_added_from_obs_table',),
#  ('GMF_added_to_sinks',),
#  ('YigoBarrelObs',),
#  ('crb_obs',),
#  ('fumigation',),
#  ('ground_treatment',),
#  ('matt',),
#  ('person',),
#  ('rearing',),
#  ('rearing_curr',),
#  ('rearing_obs',),
#  ('rearing_old',),
#  ('search',),
#  ('search_track',),
#  ('search_tracker_2',),
#  ('sink2',),
#  ('sink_visit2',),
#  ('tempAdultsPerTrapDay',),
#  ('tempAdultsTrapped',),
#  ('tempFinalResults',),
#  ('tempMinStartDate',),
#  ('tempNearbyTraps',),
#  ('tempTrapCatch',),
#  ('tempTrapCatchResults',),
#  ('tempTrapCatchSummary',),
#  ('tempTrapsInBoundingBox',),
#  ('test',),
#  ('trap',),
#  ('trapSpatial',),
#  ('trap_extras',),
#  ('trap_visit',),
#  ('tree',),
#  ('tree_treatment',),
#  ('xtrap catch by trapType',),
#  ('xtrap release rates',),
#  ('xtrap release rates2',),
#  ('xtrap_cycles',),
#  ('xtrap_location',),
#  ('xtrap_visit',)]
